# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %%
# Define a function scraping soundtracks from imdb by movie ID

def get_imdb_soundtrack(imdb_id):
    url = f"https://www.imdb.com/title/{imdb_id}/soundtrack"
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)

    if response.status_code != 200:
        print("Error loading page")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')
    lis = soup.find_all('li')

    tracks = []
    for li in lis:
        text = li.get_text(strip=True)
        # Only include lines that look like soundtrack data
        '''
        if any(kw in text for kw in ['Written', 'Performed', 'Sung', 'Recorded', 'Courtesy']):
            tracks.append(text)
        '''
        if 'by' in text :
            tracks.append(text)

    return tracks

# %%
soundtrack_list = get_imdb_soundtrack("tt0095853")
for i, line in enumerate(soundtrack_list):
    print(f"{i+1}. {line}")
# Out:
# 1. Baby the TransWritten, Performed & Produced byJoe StrummerJoe Strummer performs courtesy of CBS Records United Kingdom Limited
# 2. Nothin' 'Bout Nothin'Written, Performed & Produced byJoe StrummerJoe Strummer performs courtesy of CBS Records United Kingdom Limited
# 3. Trash CityWritten, Performed & Produced byJoe StrummerJoe Strummer performs courtesy of CBS Records United Kingdom Limited
# 4. Nefertiti RockWritten, Performed & Produced byJoe StrummerJoe Strummer performs courtesy of CBS Records United Kingdom Limited
# 5. Cholo VestWritten, Performed & Produced byJoe StrummerJoe Strummer performs courtesy of CBS Records United Kingdom Limited
# 6. Something HappenedWritten & Performed byLou ReedProduced byLou Reed&Arthur Baker
# 7. H.M.S. Pinafore ExcerptsWritten byW.S. Gilbert&Arthur Sullivan
# 8. She's on My MindWritten by John HusseyPerformed & Produced byLittle AmericaLittle America performs courtesy of Geffen Records
# 9. Waiting on LoveWritten byKurt Neumann&Sammy Llanas(as Sam Llanas)Performed byBoDeansProduced by Jim ScottBoDeans performs courtesy of Slash/Reprise Records
# 10. Never Looking BackWritten byDavid KahnePerformed by Michael Ruff
# 11. 'Cause I Said SoWritten, Performed & Produced byThe GodfathersCourtesy of Epic Records
# 12. All Day and All of the NightWritten byRay Davies&Dave DaviesPerformed byThe StranglersProduced byThe Stranglers& Ted HaytonCourtesy of CBS Records United Kingdom Limited
# 13. Symphony No. 5, AdagiettoWritten byGustav MahlerPerformed byBrian Banks&Anthony Marinelli
# 14. Moon RiverWritten byJohnny Mercer&Henry Mancini
# 15. Wishing on Another Lucky StarWritten byJD SoutherA cappella version performed by Shea Adamson
# 16. Wishing on Another Lucky StarWritten & Performed byJD SoutherProduced byJD Souther&Waddy Wachtel

# %%
# Read the curated movie list csv file
df_movies = pd.read_csv("Movie List.csv")
movie_ids = df_movies['IMDb ID'].to_list()
df_movies.head()
# Out:
#                     Movie Title  Year  \
# 0                      SLC Punk  1998
# 1          SubUrbia (Linklater)  1996
# 2  Suburbia (Penelope Spheeris)  1983
# 3                   Smithereens  1982
# 4                   Ghost World  2001
#
#                                        Vibe Keywords    IMDb ID
# 0  rebellious nostalgia, punk decay, emotional chaos  tt0133189
# 1      aimlessness, Gen X burnout, parking lot dread  tt0120238
# 2             raw punk squat teens, emotional vacuum  tt0086589
# 3       NYC no wave desperation, scene-girl collapse  tt0084698
# 4       post-high school alienation, ironic distance  tt0162346

# %%
all_data = []

# You already have this:
# movie_ids = df_movies['IMDb ID'].to_list()

# Assume df_movies also has the movie titles
for _, row in df_movies.iterrows():
    title = row['Movie Title']  # or whatever column contains the title
    imdb_id = row['IMDb ID']
    
    print(f"Scraping {title} ({imdb_id})")
    raw_lines = get_imdb_soundtrack(imdb_id)

    for line in raw_lines:
        all_data.append({
            "movie": title,
            "imdb_id": imdb_id,
            "raw_track": line
        })
# Out:
# Scraping SLC Punk (tt0133189)
# Scraping SubUrbia (Linklater) (tt0120238)
# Scraping Suburbia (Penelope Spheeris) (tt0086589)
# Scraping Smithereens (tt0084698)
# Scraping Ghost World (tt0162346)
# Scraping Out of the Blue (tt0081291)
# Scraping Ladies and Gentlemen, The Fabulous Stains (tt0082639)
# Scraping Times Square (tt0081635)
# Scraping River’s Edge (tt0091860)
# Scraping Permanent Record (tt0095853)
# Scraping Gummo (tt0119237)
# Scraping Kids (tt0113540)
# Scraping The Doom Generation (tt0112887)
# Scraping My Own Private Idaho (tt0102494)
# Scraping We Are the Best! (tt2364975)
# Scraping Mid90s (tt5613484)
# Scraping Paranoid Park (Gus Van Sant) (tt0842929)
# Scraping Wild Tigers I Have Known (tt0430768)
# Scraping Slacker (tt0102943)
# Scraping Nowhere (tt0119809)

# %%
df_soundtracks = pd.DataFrame(all_data)
df_soundtracks.to_csv("all_soundtracks_raw.csv", index=False)

# %%
# Define a function to parse and extract track title and artist

def parse_track_entry_clean(entry):
    # Extract title (everything before "Written by" or "Performed by")
    title_match = re.split(r"Written|Performed|Courtesy|Lyrics by", entry)
    title = title_match[0].strip()

    print(title)

    # Try to extract performer
    performer_match = re.search(
    r"(?:Performed by|Performed & Written by|Sung by|Written, Performed & Produced by)\s*([\w\s\.\-&'()]+)",
    entry
    )

    artist = None

    if performer_match:
        artist = performer_match.group(1)
        artist = re.split(r"from|Under license|Courtesy of|Published by|Written by|Played at", artist, flags=re.IGNORECASE)[0]
        artist = artist.replace("&", " & ").replace("  ", " ").strip()
    

    return {
        "track": title,
        "artist": artist if artist else None
    }

# %%
# Define a function to parse and extract track title and artist

def parse_track_entry_clean(entry):
    # Extract title (everything before "Written by" or "Performed by")
    title_match = re.split(r"Written|performed|Performed|Courtesy|Lyrics by|Words and Music by", entry)
    title = title_match[0].strip()

    print(title)

    # Try to extract performer
    performer_match = re.search(
    r"(?:Performed by|performed by|Performed & Written by|Sung by|Written, Performed & Produced by|Written and Recorded by|Recorded by|Performed & Composed by|Written & Performed by|Performed & Produced by)\s*([\w\s\.\-&'()]+)",
    entry
    )

    artist = None
    remixer = None

    
    if performer_match:
        artist = performer_match.group(1)
        artist = re.split(r"from|Under license|Courtesy of|Published by|Written|Played at|Composed by|Produced by|Approved by|\(c\|Copyright|Recording|Conducted by|Recycled by", artist, flags=re.IGNORECASE)[0]
        artist = artist.replace("&", " & ").replace("  ", " ").strip()

        if "Remixed by" in artist:
            artist, remixer = artist.split("Remixed by", 1)
            artist = artist.strip()
            remixer = remixer.strip()

    if "byPowder Blues Band" in entry:
        title = entry.replace("byPowder Blues Band", "").strip()
        artist = "Powder Blues Band"

    return {
        "track": title,
        "artist": artist if artist else None,
        "remixer": remixer if remixer else None
    }

# %%
parsed_rows = []

for _, row in df_soundtracks.iterrows():
    parsed = parse_track_entry_clean(row['raw_track'])
    parsed['movie'] = row['movie']
    parsed['imdb_id'] = row['imdb_id']
    parsed_rows.append(parsed)

df_parsed = pd.DataFrame(parsed_rows)
# Out:
# High Adventure
# Sex & Violence
# Too Hot
# Mirror in the Bathroom
# Champaign Breakfast
# Little Ocean
# 1969
# Pooh Bare
# I Love Livin' in the City
# No More Bullshit
# Fear & Loathing
# Train Wreck
# Little Doll
# Cretin Hop
# I Never Promised You a Rose Garden
# Gypsy Tango
# One of These Days
# She's The One
# Gasoline Rain
# Gangsters
# Beat My Guest
# Mexican Dance
# Lazy River
# Bluegrass Blues
# Hot For Teacher
# Urban Struggle
# Through the Town
# Istanbul Coffee House
# Moonlight Sonata
# Free to Live
# Wreck We 'Em
# We Will Fall
# Look Back & Laugh
# Rock & Roll
# Requiem
# Mother of Pearl
# Dreaming
# She Loved Like Diamonds
# Amoeba
# The Trees
# Kiss Me Deadly
# Kill the Poor
# Town Without Pity
# Peaceful Day
# Scum
# Rundown
# NWO
# Bulletproof Cupid
# Unheard Music
# Feather in Your Cap
# Does Your Hometown Care
# Bee-Bee's Song
# Man Invisible
# Psychic Hearts
# Human Cannonball
# SalvationMusic byBill Carter
# Candle
# Hot Day
# Huge Giant Omen
# I'm Not Like Everybody Else
# Sunday
# Cult
# Richard Hung Himself
# Wash Away
# Darker My Love
# The Legend Of Pat Brown
# No God
# Urban Struggle
# The Boy with the Perpetual Nervousness
# Loveless Love
# Original Love
# I Never Felt
# Guitar Beat
# Another World
# The Kid with the Replaceable Head
# Out Of Baby's Reach
# Devious Woman
# Copacabana(uncredited)
# Moody
# Jaan Pehechaan Ho
# Graduation Rap
# Mister Magic
# Where Is the Love
# A Tender Moment
# Never Gonna Stop
# Bucket
# Hooked On You
# Happy Shoppers
# Disco Hippy
# Find a Way to Win
# Gonna Have Fun
# Zine-O-Phobia Music
# What Do I Get?
# Devil Got My Woman
# Let's Go Riding
# Going My Way
# Stargate Trailer
# The Pinnacle
# Georgia On My Mind
# I Must Have It
# Scalding Hot Coffee Rag
# Surfin' Planet Speedball
# Pickin' Cotton Blues
# Blueshammer Blues
# Venezuela
# You're Just My Type
# Bertha Lands
# Warning
# Mezzanine Dream
# Miranda
# Solid (As a Rock)
# Blues for Basie
# Clarice
# Las Palmas De Maracaibo
# A Smile and a Ribbon
# Heartbreak Hotel
# My My, Hey Hey (Out of the Blue)
# Teddy Bear
# Thrasher
# Out of Luck
# Somebody's Mom
# Sorry Just Won't Do
# Blue MotelbyPowder Blues Band
# What Have I Been Drinkin'byPowder Blues Band
# Doin' It RightbyPowder Blues Band
# All Washed Up
# It's You I Need
# Curfew
# Movin'
# Waste of TimeMusic byBarry Ford
# Professionals
# Professionals
# La La La
# Don't Blow It All the Way
# Conned Again
# Roadmap of My Tears
# I Slept in an Arcade
# Will You Still Love Me Tomorrow
# You Can't Hurry LoveComposed byBrian Holland(as Holland),Lamont Dozier(as Dozier),Eddie Holland(as Holland)
# Dangerous Type
# Grinding Halt
# The Night Was Not
# Pretty Boys
# Innocent, Not Guilty
# Flowers in the City(credit only)
# Damn Dog
# Your Daughter Is One
# Help Me!
# Down in the Park
# Talk of the Town
# Rock Hard
# I Wanna Be Sedated
# Walk on the Wild Side
# Same Old Scene
# Babylon's Burning
# Pissing in the River
# Life During Wartime
# Take This Town
# Kyrie Eleison
# Captor of Sin
# Tormentor
# Evil Has No Boundaries
# Die by the Sword
# Lethal Tendencies
# Let Me Know
# Fire in the Rain
# Happy Day
# Let's Go, Let's Go, Let's Go
# I'm Gonna Miss You
# Baby the Trans
# Nothin' 'Bout Nothin'
# Trash City
# Nefertiti Rock
# Cholo Vest
# Something Happened
# H.M.S. Pinafore Excerpts
# She's on My Mind
# Waiting on Love
# Never Looking Back
# 'Cause I Said So
# All Day and All of the Night
# Symphony No. 5, Adagietto
# Moon River
# Wishing on Another Lucky Star
# Wishing on Another Lucky Star
# My Little Rooster
# Everyday
# My Bonnie
# Nothing But Da Bone in Me
# Like a Prayer
# Suite #1 for Solo Cello
# La Rosita
# Crying
# Jesus Loves Me
# Give the Human Devil His Due
# Equimanthorn
# Little Baby
# Rundgang um die Transzendentale Saule der Singularitat
# Verschleierte Irrelgiositat
# Schuld Uns'ves Knoch'rigen Falt Pferds
# Cat Killer (D.W.S.O.B.)
# Dragonaut
# Some Grass
# Mom and Dad's Pussy
# Rite of Cleansure (Dominus Sathanas Demo)(uncredited)
# Smokin' Husks(uncredited)
# Pow
# In 3's
# Sabrosa
# Whutcha Want
# Da Bichez
# I'm the One
# Word Is Bond
# Crooklyn (Instrumental)
# Wrong Side of the Tracks
# Spoiled
# Traneing In
# Casper
# Day-OTraditional, lyrics byWilliam A. AttawayandIrving Burgie[Incorrectly credited as written byWilliam A. AttawayandIrving Burgie]Copyright © 1955, Renewed 1983Lord Burgess Music Publishing Company (ASCAP)Cherry Lane Music Publishing Inc. (ASCAP)Administered by Cherry Lane Music Publishing Inc.
# Daddy Never Understood
# Dancing in the Dark
# Sunday Bloody Sunday
# Danny Boy
# Mad Fright Night
# Casper the Friendly Ghost
# Oh My God (Remix Version)
# Listen Up
# Time's Up
# Heresy
# Double Coupon
# Religion (Pussywhipped Mix)
# Drag Me Down
# Alison
# This Heaven
# First Dark Ride
# On the Wheel
# Christianity
# Dogs Rule the Night
# One (The Full-On Jack Dangers Mix)
# But If You Go
# Penetration
# Soul Driver
# Groovy Is My Name
# Summerblink
# On
# Sometimes Always
# Paradise (Now Remix)
# Slut
# Undertow (The Spooky Mix)
# Leave Them All Behind
# Violator
# Dancing Gold
# Already There
# Blue Skied an' Clear
# Cattle Call
# Deep Night
# Mr. KleinMusic Composed byTom Dokoupil
# Home on the RangeMusic Composed byDaniel E. Kelley(as Daniel E. Kelley)
# America, the BeautifulMusic Composed bySamuel A. Ward
# Bachu BerTraditional Dauphinoise Melody
# Too Many Colors
# Ovoniam IpseMusic Composed by Thomas Stoltzer
# Nun Freut EuchMusic Composed by Thomas Stoltzer
# Cherish
# Blue EyesMusic Composed byElton John
# The Old Main Drag
# When the Saints Go Marchin' InMusic Composed by J.M. Black
# The FuneralsMusic Composed by Anthony Holborne
# Der AdlerMusic Composed byTom Dokoupil
# Getting Into the Outside
# Schweden Schweden
# Kär och galen
# Love at Last
# Sex Noll Två
# Don't You Want Me
# Iron Fist
# Häng Gud
# Sonate d-moll prelude xodo de baiana
# Sällskapa mig genom natten
# Villiers Terrace
# Hata sport
# Stupet
# Sex Noll Två
# Leva i smyg
# Vad skall du bli
# Brezjnev Reagan-Fuck off
# Mental istid
# Den jävla sporten
# Jag vill dö
# KumbayaPublic Domain
# Kiss from a Rose
# 93 'Til Infinity
# Wave of Mutilation (U.K. Surf)
# Ya Playin' Yaself
# Put It On
# Supertouch / Shitfit
# Hybrid Moments
# Sucka Nigga
# Dedicated to the One I Love
# I'm That Type of Nigga
# A Normal Man Running
# Gyöngyhajú lány
# Hooligans
# Pepita
# 1-800-Suicide
# Watermelon Man
# When the Shit Goes Down
# Where Did You Sleep Last Night (Live Version)
# Girlfriend
# Pony
# Mistadobalina
# We'll Let You Know
# Liquid Swords
# Dance
# Passin' Me By
# La Porticina SegretafromJuliet of the Spirits (1965)
# Song 1
# La Chambre Blanche
# Walk Through Resonant Landscape #2
# I Can Help
# The White Lady Loves You More
# Symphony No. 9 in D Minor, Op. 125Composed byLudwig van Beethoven(as Ludwig Beethoven)Published by ZZFC (ASCAP/PRS)
# Outlaw
# L'Arcobaleno per GiuliettafromJuliet of the Spirits (1965)
# Tunnelmouth Blues
# We Will Revolt
# Song 3
# I Heard That
# Dedans dehors
# Song 2
# Il Giardino delle FatefromJuliet of the Spirits (1965)
# Rugiada Sui RanocchifromJuliet of the Spirits (1965)
# La Gradisca e il PrincipefromAmarcord (1973)
# Angeles
# Strongest Man in the World
# Youth Riot
# Ghoulish
# When I Was in My Prime
# The Night Knows Nothing At All
# Nocturne in E Flat Major
# Wild Whiskey
# Crater Full of Goldfish
# High Stars
# Mighty
# Se I Miei Sospiri
# The Heart Harmonicon
# Your Heart is So Loud
# O Mio Babbino Caro
# Idumea
# A Soft Voice Whispers Nothing
# Wild Tigers I Have Known
# Disturbed Young Man (With a Tan)
# White WallsWords byScott MarcusMusic by Glass Eye
# Lackluster
# Bills
# Big Business Monkey
# Lula's Bar & Pool
# Seven Song
# Jesus Is Coming Soon (To a Theatre Near You)
# Brand New Day
# Colored F.B.I. Guy
# America's King
# Brothers Grimm
# White Bread
# Little Black Sunrise
# Killer Rockers
# Charlie
# They'll Love You For It
# Sedrick
# Ventricular Refibulation
# Aphrodite
# Fight It Out
# Die Graskop Polka
# Strangers Die Everyday
# Skokiaan(uncredited)
# Avalyn II
# Intravenous
# Dicknail
# Two of Hearts
# Daydreaming (The Blacksmith Remix)
# Seekers Who Are Lovers (The Otherness Mix)
# Five Fingers
# Thursday Treatments
# Get A Helmet
# Life Is Sweet (Daft Punk Mix)
# "Killing Time (Qureysh -EH?1 Remix)
# I Have The Moon
# Hendrix Necro
# Nowhere
# Papua New Guinea (Massey Mix)
# She's So High
# Grey Skies
# Memorabilia
# Flippin' Tha Bird (The Ceasefire Remix)
# Tryin' To Reach You
# Take Another
# Air-Eyes
# In The Black
# Kick It
# Time To Find Me
# Mourning Air
# Vendetta
# Out Of My Tree
# How Can You Be Sure?
# Kiddie Grinder (Remix)
# Trash
# The Snow: Answers Come In Dreams
# In The City
# The Next Room Of The Dream
# Freak Out
# Land Beyond The Sun
# Generation Wrekkked (Danny Saber Remix)
# Dose (The Critter Mix)
# Love Is Stronger Than Death

# %%
df_parsed.head()
# Out:
#                     track                       artist remixer     movie  \
# 0          High Adventure                         None    None  SLC Punk
# 1          Sex & Violence  The Exploited(as Exploited)    None  SLC Punk
# 2                 Too Hot                 The Specials    None  SLC Punk
# 3  Mirror in the Bathroom                         Fifi    None  SLC Punk
# 4     Champaign Breakfast                  John Sbarra    None  SLC Punk
#
#      imdb_id
# 0  tt0133189
# 1  tt0133189
# 2  tt0133189
# 3  tt0133189
# 4  tt0133189

# %%
df_parsed.tail()
# Out:
#                                        track                artist  \
# 409                                Freak Out                   311
# 410                      Land Beyond The Sun  Flying Saucer Attack
# 411  Generation Wrekkked (Danny Saber Remix)               Chuck D
# 412                   Dose (The Critter Mix)                Filter
# 413              Love Is Stronger Than Death               The The
#
#          remixer    movie    imdb_id
# 409         None  Nowhere  tt0119809
# 410         None  Nowhere  tt0119809
# 411  Danny Saber  Nowhere  tt0119809
# 412      Critter  Nowhere  tt0119809
# 413         None  Nowhere  tt0119809

# %%
len(df_parsed.groupby('movie'))
# Out:
# 20

# %%
df_parsed.groupby('movie').size()
# Out:
# movie
# Ghost World                                  36
# Gummo                                        21
# Kids                                         22
# Ladies and Gentlemen, The Fabulous Stains    13
# Mid90s                                       25
# My Own Private Idaho                         16
# Nowhere                                      39
# Out of the Blue                              10
# Paranoid Park (Gus Van Sant)                 20
# Permanent Record                             16
# River’s Edge                                 11
# SLC Punk                                     42
# Slacker                                      24
# Smithereens                                  11
# SubUrbia (Linklater)                         20
# Suburbia (Penelope Spheeris)                  6
# The Doom Generation                          26
# Times Square                                 20
# We Are the Best!                             20
# Wild Tigers I Have Known                     16
# dtype: int64

# %%
df_parsed.to_csv('Soundtrack Parsed.csv', index=False, encoding='utf-8')
